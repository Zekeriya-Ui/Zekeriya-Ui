# %% [markdown]
# <a href="https://colab.research.google.com/github/Zekeriya-Ui/Zekeriya-Ui/blob/main/Applied_Data_Science_Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Overview of Completed Projects

# %% [markdown]
# *   **Predicting House Prices in Mexico**: This project involved using various data science techniques to predict house prices, likely incorporating features such as location, size, amenities, and market trends within the Mexican real estate market.

# %% [markdown]
# *   **Predicting Apartment Prices in Buenos Aires**: Similar to the Mexico project, this focused on forecasting apartment prices in Buenos Aires, Argentina, considering local market dynamics, property characteristics, and economic indicators.

# %% [markdown]
# *   **Predicting Air Quality in Nairobi**: This project likely utilized environmental data, meteorological conditions, and potentially traffic or industrial emissions to predict air quality levels in Nairobi, Kenya, aiming to provide insights for public health or policy-making.

# %% [markdown]
# *   **Predicting Earthquake Damage in Nepal**: This project would have involved analyzing data related to seismic activity, building structures, geological features, and historical damage to predict the extent of damage from earthquakes in Nepal, which could be crucial for disaster preparedness and response.

# %% [markdown]
# *   **Predicting Bankruptcy in Poland**: This project likely used financial indicators, economic data, and corporate performance metrics to develop models that predict the likelihood of bankruptcy for companies in Poland, offering valuable insights for investors, creditors, and regulatory bodies.
